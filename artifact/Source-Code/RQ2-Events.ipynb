# %%
from moralis import evm_api

# %%
import pandas as pd

# Read the dataframe from a file or create it manually
df = pd.read_csv('NewImplementation(address,address).csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_column = df['address']

# %%
import requests
import json
import logging
import pandas as pd

# %%
# NewImplementation(address,address)
api_key = "xx" #Replace with your API Key
for address in header_column:
    params = {
        "address": address,
        "topic": "0xd604de94d45953f9138079ec1b82d533cb2160c906d1076d1f7ed54befbca97a", #Topic specific for the event
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
    body ='{"anonymous":false,"inputs":[{"indexed":false,"internalType":"address","name":"oldImplementation","type":"address"},{"indexed":false,"internalType":"address","name":"newImplementation","type":"address"}],"name":"NewImplementation","type":"event"}' #The ABI for the event
    body = json.loads(body)

    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))

        # Save event logs to a JSON file for each contract address
        with open('NewImplementation(address,address).json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue

# %%
dfXX = pd.read_csv('Upgraded(address)XX.csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_columnXX = dfXX['address']

# %%
# Upgraded(address)
api_key = "X" #Replace with your API Key
#x=153001
#start_index = 153001  # Change this to the index you want to start from
for address in header_columnXX:
    params = {
        "address": address,
        "topic": "0xbc7cd75a20ee27fd9adebab32041f755214dbc6bffa90cc0225b39da2e5c2d3b", #this represent the topic of the event
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
    body ='{"anonymous":false,"inputs":[{"indexed":true,"name":"implementation","type":"address"}],"name":"Upgraded","type":"event"}' #The ABI for the event
    body = json.loads(body)
    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))
        print(x)
        x=x+1
        # Save event logs to a JSON file for each contract address
        with open('Upgraded(address)X.json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue

# %%
df2 = pd.read_csv('ProxyUpdated(address,address).csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_column2 = df2['address']

api_key = "xx" #Replace with your API Key
for address in header_column2:
    params = {
        "address": address,
        "topic": "0xd32d24edea94f55e932d9a008afc425a8561462d1b1f57bc6e508e9a6b9509e1",# Topic for specific event
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
    body ='{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"_new","type":"address"},{"indexed":true,"internalType":"address","name":"_old","type":"address"}],"name":"ProxyUpdated","type":"event"}'
    body = json.loads(body)
    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))

        # Save event logs to a JSON file for each contract address
        with open('ProxyUpdated(address,address).json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue

# %%
df3 = pd.read_csv('ImplementationUpdated(address).csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_column3 = df3['address']

api_key = "XX" #Replace with your API Key
for address in header_column3:
    params = {
        "address": address,
        "topic": "0x310ba5f1d2ed074b51e2eccd052a47ae9ab7c6b800d1fca3db3999d6a592ca03",
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
   # body = '{"anonymous":false,"inputs":[{"indexed":false,"internalType":"contract Proxyable","name":"newTarget","type":"address"}],"name":"TargetUpdated","type":"event"}'
    body ='{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"newImplementation","type":"address"}],"name":"ImplementationUpdated","type":"event"}'
    body = json.loads(body)
    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))

        # Save event logs to a JSON file for each contract address
        with open('ImplementationUpdated(address).json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue

# %%
df4 = pd.read_csv('Upgraded(uint256,address).csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_column4 = df4['address']

api_key = "xx" #Replace with your API Key
for address in header_column4:
    params = {
        "address": address,
        "topic": "0x4289d6195cf3c2d2174adf98d0e19d4d2d08887995b99cb7b100e7ffe795820e",
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
    body ='{"anonymous":false,"inputs":[{"indexed":false,"name":"version","type":"uint256"},{"indexed":true,"name":"implementation","type":"address"}],"name":"Upgraded","type":"event"}'
    body = json.loads(body)
    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))

        # Save event logs to a JSON file for each contract address
        with open('Upgraded(uint256,address).json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue

# %%
df5 = pd.read_csv('ImplChanged(address,address).csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_column5 = df5['address']

api_key = "xx" #Replace with your API Key
for address in header_column5:
    params = {
        "address": address,
        "topic": "0xaad46b89531ed10d02d926f4d6bfe234a6126e3fffc02d3b07167575f9c14337",
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
    body ='{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"_oldImpl","type":"address"},{"indexed":true,"internalType":"address","name":"_newImpl","type":"address"}],"name":"ImplChanged","type":"event"}'
    body = json.loads(body)
    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))

        # Save event logs to a JSON file for each contract address
        with open('ImplChanged(address,address).json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue

# %%
df6 = pd.read_csv('NewImplementation(bytes32,bytes32,address).csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_column6 = df6['address']

api_key = "xx" #Replace with your API Key
for address in header_column6:
    params = {
        "address": address,
        "topic": "0xb6995687d7ca103560700935c62676d62918daf01877efebce4eeeeb6bedd512",
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
    body ='{"anonymous":false,"inputs":[{"indexed":false,"internalType":"bytes32","name":"key","type":"bytes32"},{"indexed":false,"internalType":"bytes32","name":"name","type":"bytes32"},{"indexed":false,"internalType":"address","name":"implementation","type":"address"}],"name":"NewImplementation","type":"event"}' 
    body = json.loads(body)
    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))

        # Save event logs to a JSON file for each contract address
        with open('NewImplementation(bytes32,bytes32,address).json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue

# %%
df7 = pd.read_csv('TargetUpdated(address).csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_column7 = df7['address']

api_key = "xx" #Replace with your API Key
for address in header_column7:
    params = {
        "address": address,
        "topic": "0x814250a3b8c79fcbe2ead2c131c952a278491c8f4322a79fe84b5040a810373e",
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
    body = '{"anonymous":false,"inputs":[{"indexed":false,"internalType":"contract Proxyable","name":"newTarget","type":"address"}],"name":"TargetUpdated","type":"event"}'
    body = json.loads(body)
    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))

        # Save event logs to a JSON file for each contract address
        with open('TargetUpdated(address).json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue

# %%
df8 = pd.read_csv('FunctionUpdate(bytes4,address,address,string).csv')  # Replace 'your_file.csv' with your actual file name

# Assuming the first column is named 'Header'
header_column8 = df8['address']

api_key = "xx" #Replace with your API Key
for address in header_column8:
    params = {
        "address": address,
        "topic": "0x3234040ce3bd4564874e44810f198910133a1b24c4e84aac87edbf6b458f5353",
        "chain": "eth",
        "disable_total": False,
        "limit": 0
    }
    body ='{"anonymous":false,"inputs":[{"indexed":true,"internalType":"bytes4","name":"functionId","type":"bytes4"},{"indexed":true,"internalType":"address","name":"oldDelegate","type":"address"},{"indexed":true,"internalType":"address","name":"newDelegate","type":"address"},{"indexed":false,"internalType":"string","name":"functionSignature","type":"string"}],"name":"FunctionUpdate","type":"event"}' 
    body = json.loads(body)
    try: 
        result = evm_api.events.get_contract_events(
            api_key=api_key,
            params=params,
            body=body,
        )
        print(json.dumps(result, indent=4))

        # Save event logs to a JSON file for each contract address
        with open('FunctionUpdate(bytes4,address,address,string).json', 'a', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=4)

    except Exception as e:
        # Handle the error as per your requirement
        # For example, you can log the error
        logging.error(f"Error occurred for address {address}: {e}")
        # Or print a custom error message
        print(f"Error occurred for address {address}: {e}")
        # Or simply ignore the error and continue with the next iteration
        continue
